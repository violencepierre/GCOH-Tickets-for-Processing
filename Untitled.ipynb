# %%
import numpy as np

# %%
a = np.array([2,4,1])
b = np.array([1,1,1])

# %%
a+b
# Out:
# array([3, 5, 2])

# %%
a-b
# Out:
# array([1, 3, 0])

# %%
a*b
# Out:
# array([2, 4, 1])

# %%
sc=2

# %%
sc*a
# Out:
# array([4, 8, 2])

# %%
lista=[2,4,1]
print(lista)
# Out:
# [2, 4, 1]

# %%
listasarray=np.array(lista)
print(listasarray)
# Out:
# [2 4 1]

# %%
sc*lista
# Out:
# [2, 4, 1, 2, 4, 1]

# %%
sc*listasarray
# Out:
# array([4, 8, 2])

# %%
a = np.array([2,4,1])
b = np.array([1,1,1])

# %%
np.dot(a,b)
# Out:
# np.int64(7)
